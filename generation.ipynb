# %% [markdown]
# # Esta notebook se utilizara a todo lo referido a la creación de datos

# %%
#Imports
from models import BinPackingGame, Box

# %%
container = Box(4, 4)
boxes = [Box(4, 1), Box(4, 3)]
bin_packing_game = BinPackingGame(container, boxes)
print(bin_packing_game.solve())
# Out:
# ResolvedBinPackingGameResult(positions=[(0, 0), (1, 0)])

# %% [markdown]
# ### Rotaciones y Orden de las Cajas
# Dependiendo de cómo un algoritmo resuelve el problema de bin packing problema, tener cajas con dimensiones (ancho, alto) alternadas o incluso el orden de las cajas puede dar distintos resultados, por lo cuál a la hora de la generación tenemos que considerar que:
# 1. `Box(w, h)` es distinto de `Box(h,w)` a menos que `w=h`
# 2. La sequencia `[Box1, Box2]` es disitinta de `[Box2, Box1]` a menos que `Box1=Box2`

# %%
# Comparacion de cajas y rotaciones
box1 = Box(2, 3)
box2 = Box(2, 3)
assert box1 == box2, "Las cajas son iguales"
assert hash(box1) == hash(box2), "Los hashes son iguales"
box1 = Box(2, 3)
box2 = Box(5, 4)
assert box1 != box2, "Las cajas son diferentes"
assert hash(box1) != hash(box2), "Los hashes son diferentes"
box1 = Box(2, 3)
box2 = box1.rotate()
assert box1 != box2, "Las cajas son diferentes"
assert hash(box1) != hash(box2), "Los hashes son diferentes"
box1 = Box(3, 3)
box2 = box1.rotate()
assert box1 == box2, "Las cajas son iguales"
assert hash(box1) == hash(box2), "Los hashes son iguales"
print("Comparacion de cajas y rotaciones exitosa")

# Comparacion de orden de cajas
boxes1 = [Box(2, 3), Box(3, 4)]
boxes2 = [Box(2, 3), Box(3, 4)]
assert boxes1 == boxes2, "Las sequencias son iguales"
boxes1 = [Box(2, 3), Box(3, 4)] 
boxes2 = [Box(3, 4), Box(2, 3)]
assert boxes1 != boxes2, "Las sequencias son diferentes"
print("Comparacion de orden de cajas exitosa")
# Out:
# Comparacion de cajas y rotaciones exitosa
# Comparacion de orden de cajas exitosa

# %% [markdown]
# ### BinPackingGame Key
#
# Tenemos que asegurarnos que un problema es igual a otro si y solo si el contenedor es el mismo y la sequencia de cajas es la misma

# %%
bpm1 = BinPackingGame(Box(4, 4), [Box(4, 1), Box(4, 3)])
bpm2 = BinPackingGame(Box(4, 4), [Box(4, 1), Box(4, 3)])
assert bpm1 == bpm2, "Los juegos son iguales"
assert hash(bpm1) == hash(bpm2), "Los hashes son iguales"
bpm1 = BinPackingGame(Box(4, 4), [Box(4, 1), Box(4, 3)])
bpm2 = BinPackingGame(Box(5, 5), [Box(4, 1), Box(4, 3)])
assert bpm1 != bpm2, "Los juegos son diferentes"
assert hash(bpm1) != hash(bpm2), "Los hashes son diferentes"
bpm1 = BinPackingGame(Box(4, 4), [Box(4, 1), Box(4, 3)])
bpm2 = BinPackingGame(Box(4, 4), [Box(4, 3), Box(4, 1)])
assert bpm1 != bpm2, "Los juegos son diferentes"
assert hash(bpm1) != hash(bpm2), "Los hashes son diferentes"
print("Comparacion de juegos exitosa")
# Out:
# Comparacion de juegos exitosa

# %% [markdown]
# ### Data Augmentation
#
# Ahora que definimos que 2 problemas son considerados distintos tan solo por permutar cajas o directamente rotar una caja (incluso el contenedor), dado una solución válida del problema podemos generar muchos problemas diferentes, y también válidos!

# %%
from itertools import permutations, product
from typing import List

from models import ResolvedBinPackingGameResult

def generate_box_rotations(boxes):
        return [[box, box.rotate()] for box in boxes]

class BinPackingGameManager:
    def __init__(self):
        self.games = set()

    def __len__(self):
        return len(self.games)
    
    def __getitem__(self, index):
        return self.games[index]
    
    def __iter__(self):
        return iter(self.games)
    
    def add_game(self, game, max_permutations = 1000):
        """
        Agrega un juego a la lista de juegos si no existe un juego igual y agrega todas las permutaciones de las cajas
        con sus posibles rotaciones y rotando también el contenedor.
        Args:
            game (BinPackingGame): Juego a agregar
            max_permutations (int): Máximo de permutaciones a generar para el juego dado
        Returns:
            Int: 0 si el juego ya existe, N donde N es la cantidad de juegos agregados
        """
        if game in self.games:
            return 0
        rotated_containers = [game.container, game.container.rotate()]
        all_box_permutations = list(permutations(game.boxes))
        permutated_games_generated = 0
        for container in rotated_containers:
            for box_permutation in all_box_permutations:
                box_rotations = generate_box_rotations(box_permutation)
                # Generar todas las combinaciones de rotaciones para esta permutación
                for rotated_boxes in product(*box_rotations):
                    permutated_game = BinPackingGame(container, list(rotated_boxes))
                    if permutated_game not in self.games:
                        self.games.add(BinPackingGame(container, list(rotated_boxes)))
                        permutated_games_generated += 1
                        if permutated_games_generated >= max_permutations:
                            return permutated_games_generated
        return permutated_games_generated

container = Box(10, 15)
boxes = [Box(10, 4), Box(3, 6), Box(7, 2), Box(5, 5)]
game = BinPackingGame(container, boxes)
assert isinstance(game.solve(), ResolvedBinPackingGameResult), "El juego original es válido"

bpgManager = BinPackingGameManager()
games_generated = bpgManager.add_game(game, max_permutations= 1000)
print(f"{games_generated} juegos creados a partir de un juego válido con un máximo de 1000 permutaciones")
for generated_game in bpgManager:
    assert isinstance(generated_game.solve(), ResolvedBinPackingGameResult), "El juego generado es válido"
print("Todos los juegos generados son válidos")
bpgManager = BinPackingGameManager()
games_generated = bpgManager.add_game(game, max_permutations= 5)
print(f"{games_generated} juegos creados a partir de un juego válido con un máximo de 5 permutaciones")
for generated_game in bpgManager:
    print(generated_game)
# Out:
# 384 juegos creados a partir de un juego válido con un máximo de 1000 permutaciones
# Todos los juegos generados son válidos
# 5 juegos creados a partir de un juego válido con un máximo de 5 permutaciones
# BinPackingGame(container=Box(width=10, height=15), boxes=[Box(width=10, height=4), Box(width=3, height=6), Box(width=2, height=7), Box(width=5, height=5)])
# BinPackingGame(container=Box(width=10, height=15), boxes=[Box(width=10, height=4), Box(width=3, height=6), Box(width=7, height=2), Box(width=5, height=5)])
# BinPackingGame(container=Box(width=10, height=15), boxes=[Box(width=10, height=4), Box(width=6, height=3), Box(width=2, height=7), Box(width=5, height=5)])
# BinPackingGame(container=Box(width=10, height=15), boxes=[Box(width=4, height=10), Box(width=3, height=6), Box(width=7, height=2), Box(width=5, height=5)])
# BinPackingGame(container=Box(width=10, height=15), boxes=[Box(width=10, height=4), Box(width=6, height=3), Box(width=7, height=2), Box(width=5, height=5)])

# %% [markdown]
# ### Generación de problemas válidos
#
# Vamos a generar un gran cantidad de problemas a partir de un sub-conjunto de problemas válidos y los guardaremos en archivo

# %%
from models import Box
from random_generator import RandomGenerator
from utils import save

bpgManager = BinPackingGameManager()
for width in range(6, 15):
    for height in range(6, 15):
        print(f"Generando juegos para contenedor de {width}x{height}")
        container = Box(width, height)
        random_generator = RandomGenerator(
            container,
            min_container_coverage = 0.8,
            max_container_coverage = 1,
            min_boxes_per_container = 4,
            max_boxes_per_container = 10
        )
        valid_bin_packing_games = random_generator.generate(games_to_generate= 1000)
        for game in valid_bin_packing_games:
            bpgManager.add_game(game, max_permutations = 100)
        print(f"Total de juegos generados terminado el contenedor de {width}x{height}: {len(bpgManager)}")
# Out:
# Generando juegos para contenedor de 6x6
# Generated 1000 valid bin packing games in 2938 attempts
# Total de juegos generados terminado el contenedor de 6x6: 94260
# Generando juegos para contenedor de 6x7
# Generated 1000 valid bin packing games in 2566 attempts
# Total de juegos generados terminado el contenedor de 6x7: 190960
# Generando juegos para contenedor de 6x8
# Generated 1000 valid bin packing games in 2836 attempts
# Total de juegos generados terminado el contenedor de 6x8: 288860
# Generando juegos para contenedor de 6x9
# Generated 1000 valid bin packing games in 3018 attempts
# Total de juegos generados terminado el contenedor de 6x9: 387860
# Generando juegos para contenedor de 6x10
# Generated 1000 valid bin packing games in 3081 attempts
# Total de juegos generados terminado el contenedor de 6x10: 486660
# Generando juegos para contenedor de 6x11
# Generated 1000 valid bin packing games in 3472 attempts
# Total de juegos generados terminado el contenedor de 6x11: 586160
# Generando juegos para contenedor de 6x12
# Generated 1000 valid bin packing games in 3399 attempts
# Total de juegos generados terminado el contenedor de 6x12: 685760
# Generando juegos para contenedor de 6x13
# Generated 1000 valid bin packing games in 3818 attempts
# Total de juegos generados terminado el contenedor de 6x13: 785660
# Generando juegos para contenedor de 6x14
# Generated 1000 valid bin packing games in 4064 attempts
# Total de juegos generados terminado el contenedor de 6x14: 885560
# Generando juegos para contenedor de 7x6
# Generated 1000 valid bin packing games in 2849 attempts
# Total de juegos generados terminado el contenedor de 7x6: 983760
# Generando juegos para contenedor de 7x7
# Generated 1000 valid bin packing games in 2945 attempts
# Total de juegos generados terminado el contenedor de 7x7: 1081660
# Generando juegos para contenedor de 7x8
# Generated 1000 valid bin packing games in 2611 attempts
# Total de juegos generados terminado el contenedor de 7x8: 1180960
# Generando juegos para contenedor de 7x9
# Generated 1000 valid bin packing games in 2764 attempts
# Total de juegos generados terminado el contenedor de 7x9: 1279960
# Generando juegos para contenedor de 7x10
# Generated 1000 valid bin packing games in 2985 attempts
# Total de juegos generados terminado el contenedor de 7x10: 1379260
# Generando juegos para contenedor de 7x11
# Generated 1000 valid bin packing games in 3145 attempts
# Total de juegos generados terminado el contenedor de 7x11: 1478560
# Generando juegos para contenedor de 7x12
# Generated 1000 valid bin packing games in 3494 attempts
# Total de juegos generados terminado el contenedor de 7x12: 1578360
# Generando juegos para contenedor de 7x13
# Generated 1000 valid bin packing games in 3671 attempts
# Total de juegos generados terminado el contenedor de 7x13: 1678160
# Generando juegos para contenedor de 7x14
# Generated 1000 valid bin packing games in 3944 attempts
# Total de juegos generados terminado el contenedor de 7x14: 1777960
# Generando juegos para contenedor de 8x6
# Generated 1000 valid bin packing games in 2988 attempts
# Total de juegos generados terminado el contenedor de 8x6: 1876660
# Generando juegos para contenedor de 8x7
# Generated 1000 valid bin packing games in 2615 attempts
# Total de juegos generados terminado el contenedor de 8x7: 1975740
# Generando juegos para contenedor de 8x8
# Generated 1000 valid bin packing games in 3133 attempts
# Total de juegos generados terminado el contenedor de 8x8: 2075120
# Generando juegos para contenedor de 8x9
# Generated 1000 valid bin packing games in 2742 attempts
# Total de juegos generados terminado el contenedor de 8x9: 2174420
# Generando juegos para contenedor de 8x10
# Generated 1000 valid bin packing games in 2846 attempts
# Total de juegos generados terminado el contenedor de 8x10: 2274120
# Generando juegos para contenedor de 8x11
# Generated 1000 valid bin packing games in 3251 attempts
# Total de juegos generados terminado el contenedor de 8x11: 2373700
# Generando juegos para contenedor de 8x12
# Generated 1000 valid bin packing games in 3323 attempts
# Total de juegos generados terminado el contenedor de 8x12: 2473600
# Generando juegos para contenedor de 8x13
# Generated 1000 valid bin packing games in 3725 attempts
# Total de juegos generados terminado el contenedor de 8x13: 2573600
# Generando juegos para contenedor de 8x14
# Generated 1000 valid bin packing games in 3798 attempts
# Total de juegos generados terminado el contenedor de 8x14: 2673500
# Generando juegos para contenedor de 9x6
# Generated 1000 valid bin packing games in 3412 attempts
# Total de juegos generados terminado el contenedor de 9x6: 2772760
# Generando juegos para contenedor de 9x7
# Generated 1000 valid bin packing games in 3128 attempts
# Total de juegos generados terminado el contenedor de 9x7: 2872460
# Generando juegos para contenedor de 9x8
# Generated 1000 valid bin packing games in 2808 attempts
# Total de juegos generados terminado el contenedor de 9x8: 2972160
# Generando juegos para contenedor de 9x9
# Generated 1000 valid bin packing games in 2956 attempts
# Total de juegos generados terminado el contenedor de 9x9: 3071760
# Generando juegos para contenedor de 9x10
# Generated 1000 valid bin packing games in 2928 attempts
# Total de juegos generados terminado el contenedor de 9x10: 3171460
# Generando juegos para contenedor de 9x11
# Generated 1000 valid bin packing games in 3183 attempts
# Total de juegos generados terminado el contenedor de 9x11: 3271260
# Generando juegos para contenedor de 9x12
# Generated 1000 valid bin packing games in 3295 attempts
# Total de juegos generados terminado el contenedor de 9x12: 3371260
# Generando juegos para contenedor de 9x13
# Generated 1000 valid bin packing games in 3422 attempts
# Total de juegos generados terminado el contenedor de 9x13: 3471260
# Generando juegos para contenedor de 9x14
# Generated 1000 valid bin packing games in 3397 attempts
# Total de juegos generados terminado el contenedor de 9x14: 3571260
# Generando juegos para contenedor de 10x6
# Generated 1000 valid bin packing games in 3810 attempts
# Total de juegos generados terminado el contenedor de 10x6: 3670460
# Generando juegos para contenedor de 10x7
# Generated 1000 valid bin packing games in 3456 attempts
# Total de juegos generados terminado el contenedor de 10x7: 3770160
# Generando juegos para contenedor de 10x8
# Generated 1000 valid bin packing games in 3127 attempts
# Total de juegos generados terminado el contenedor de 10x8: 3869860
# Generando juegos para contenedor de 10x9
# Generated 1000 valid bin packing games in 2891 attempts
# Total de juegos generados terminado el contenedor de 10x9: 3969460
# Generando juegos para contenedor de 10x10
# Generated 1000 valid bin packing games in 3430 attempts
# Total de juegos generados terminado el contenedor de 10x10: 4069360
# Generando juegos para contenedor de 10x11
# Generated 1000 valid bin packing games in 3033 attempts
# Total de juegos generados terminado el contenedor de 10x11: 4169160
# Generando juegos para contenedor de 10x12
# Generated 1000 valid bin packing games in 3111 attempts
# Total de juegos generados terminado el contenedor de 10x12: 4269060
# Generando juegos para contenedor de 10x13
# Generated 1000 valid bin packing games in 3410 attempts
# Total de juegos generados terminado el contenedor de 10x13: 4368860
# Generando juegos para contenedor de 10x14
# Generated 1000 valid bin packing games in 3503 attempts
# Total de juegos generados terminado el contenedor de 10x14: 4468860
# Generando juegos para contenedor de 11x6
# Generated 1000 valid bin packing games in 4373 attempts
# Total de juegos generados terminado el contenedor de 11x6: 4568360
# Generando juegos para contenedor de 11x7
# Generated 1000 valid bin packing games in 3961 attempts
# Total de juegos generados terminado el contenedor de 11x7: 4667760
# Generando juegos para contenedor de 11x8
# Generated 1000 valid bin packing games in 3405 attempts
# Total de juegos generados terminado el contenedor de 11x8: 4767660
# Generando juegos para contenedor de 11x9
# Generated 1000 valid bin packing games in 3292 attempts
# Total de juegos generados terminado el contenedor de 11x9: 4867660
# Generando juegos para contenedor de 11x10
# Generated 1000 valid bin packing games in 2890 attempts
# Total de juegos generados terminado el contenedor de 11x10: 4967660
# Generando juegos para contenedor de 11x11
# Generated 1000 valid bin packing games in 3514 attempts
# Total de juegos generados terminado el contenedor de 11x11: 5067660
# Generando juegos para contenedor de 11x12
# Generated 1000 valid bin packing games in 3251 attempts
# Total de juegos generados terminado el contenedor de 11x12: 5167460
# Generando juegos para contenedor de 11x13
# Generated 1000 valid bin packing games in 3208 attempts
# Total de juegos generados terminado el contenedor de 11x13: 5267460
# Generando juegos para contenedor de 11x14
# Generated 1000 valid bin packing games in 3395 attempts
# Total de juegos generados terminado el contenedor de 11x14: 5367460
# Generando juegos para contenedor de 12x6
# Generated 1000 valid bin packing games in 4614 attempts
# Total de juegos generados terminado el contenedor de 12x6: 5467160
# Generando juegos para contenedor de 12x7
# Generated 1000 valid bin packing games in 4417 attempts
# Total de juegos generados terminado el contenedor de 12x7: 5567160
# Generando juegos para contenedor de 12x8
# Generated 1000 valid bin packing games in 3751 attempts
# Total de juegos generados terminado el contenedor de 12x8: 5667060
# Generando juegos para contenedor de 12x9
# Generated 1000 valid bin packing games in 3489 attempts
# Total de juegos generados terminado el contenedor de 12x9: 5766860
# Generando juegos para contenedor de 12x10
# Generated 1000 valid bin packing games in 3229 attempts
# Total de juegos generados terminado el contenedor de 12x10: 5866660
# Generando juegos para contenedor de 12x11
# Generated 1000 valid bin packing games in 3188 attempts
# Total de juegos generados terminado el contenedor de 12x11: 5966660
# Generando juegos para contenedor de 12x12
# Generated 1000 valid bin packing games in 3713 attempts
# Total de juegos generados terminado el contenedor de 12x12: 6066640
# Generando juegos para contenedor de 12x13
# Generated 1000 valid bin packing games in 3258 attempts
# Total de juegos generados terminado el contenedor de 12x13: 6166620
# Generando juegos para contenedor de 12x14
# Generated 1000 valid bin packing games in 3480 attempts
# Total de juegos generados terminado el contenedor de 12x14: 6266620
# Generando juegos para contenedor de 13x6
# Generated 1000 valid bin packing games in 4964 attempts
# Total de juegos generados terminado el contenedor de 13x6: 6366620
# Generando juegos para contenedor de 13x7
# Generated 1000 valid bin packing games in 4586 attempts
# Total de juegos generados terminado el contenedor de 13x7: 6466420
# Generando juegos para contenedor de 13x8
# Generated 1000 valid bin packing games in 4219 attempts
# Total de juegos generados terminado el contenedor de 13x8: 6566320
# Generando juegos para contenedor de 13x9
# Generated 1000 valid bin packing games in 4036 attempts
# Total de juegos generados terminado el contenedor de 13x9: 6666320
# Generando juegos para contenedor de 13x10
# Generated 1000 valid bin packing games in 3645 attempts
# Total de juegos generados terminado el contenedor de 13x10: 6766320
# Generando juegos para contenedor de 13x11
# Generated 1000 valid bin packing games in 3645 attempts
# Total de juegos generados terminado el contenedor de 13x11: 6866320
# Generando juegos para contenedor de 13x12
# Generated 1000 valid bin packing games in 3339 attempts
# Total de juegos generados terminado el contenedor de 13x12: 6966220
# Generando juegos para contenedor de 13x13
# Generated 1000 valid bin packing games in 3791 attempts
# Total de juegos generados terminado el contenedor de 13x13: 7065920
# Generando juegos para contenedor de 13x14
# Generated 1000 valid bin packing games in 3406 attempts
# Total de juegos generados terminado el contenedor de 13x14: 7165920
# Generando juegos para contenedor de 14x6
# Generated 1000 valid bin packing games in 5365 attempts
# Total de juegos generados terminado el contenedor de 14x6: 7265720
# Generando juegos para contenedor de 14x7
# Generated 1000 valid bin packing games in 5020 attempts
# Total de juegos generados terminado el contenedor de 14x7: 7365420
# Generando juegos para contenedor de 14x8
# Generated 1000 valid bin packing games in 4668 attempts
# Total de juegos generados terminado el contenedor de 14x8: 7465320
# Generando juegos para contenedor de 14x9
# Generated 1000 valid bin packing games in 4314 attempts
# Total de juegos generados terminado el contenedor de 14x9: 7565220
# Generando juegos para contenedor de 14x10
# Generated 1000 valid bin packing games in 4012 attempts
# Total de juegos generados terminado el contenedor de 14x10: 7665220
# Generando juegos para contenedor de 14x11
# Generated 1000 valid bin packing games in 3874 attempts
# Total de juegos generados terminado el contenedor de 14x11: 7765020
# Generando juegos para contenedor de 14x12
# Generated 1000 valid bin packing games in 3443 attempts
# Total de juegos generados terminado el contenedor de 14x12: 7865020
# Generando juegos para contenedor de 14x13
# Generated 1000 valid bin packing games in 3426 attempts
# Total de juegos generados terminado el contenedor de 14x13: 7965020
# Generando juegos para contenedor de 14x14
# Generated 1000 valid bin packing games in 3837 attempts
# Total de juegos generados terminado el contenedor de 14x14: 8065020

# %%
save(bpgManager.games, f'permutated_games.txt')
